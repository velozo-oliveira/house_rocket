# %%
import pandas as pd
data = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')

# %%
data['nivel'] = "NA"
data.loc[(data['price'] >= 0) & (data['price'] < 321950), 'nivel'] = 'nivel_0'
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      1180.0              0
# 1      7242     2.0           0     0  ...      2170.0            400
# 2     10000     1.0           0     0  ...       770.0              0
# 3      5000     1.0           0     0  ...      1050.0            910
# 4      8080     1.0           0     0  ...      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
i = 0
data['nivel'] = "NA"

for i in range(len(data)):
    if (data.loc[i,'price'] > 0) & (data.loc[i,'price'] <= 321950):
        data.loc[i,'nivel'] = "nivel_0"
        
    elif (data.loc[i,'price'] > 321950) & (data.loc[i,'price'] <= 450000):
        data.loc[i,'nivel'] = "nivel_1"
        
    elif (data.loc[i,'price'] > 450000) & (data.loc[i,'price'] <= 645000):
        data.loc[i,'nivel'] = "nivel_2"
        
    else: 
        data.loc[i,'nivel'] = "nivel_3"

print(data.head())
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      1180.0              0
# 1      7242     2.0           0     0  ...      2170.0            400
# 2     10000     1.0           0     0  ...       770.0              0
# 3      5000     1.0           0     0  ...      1050.0            910
# 4      8080     1.0           0     0  ...      1680.0              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
# Adicione as seguintes informacoes ao imovel:
#     Nome da Rua
#     Numero do imovel
#     Nome do Bairro
#     Nome da Cidade
#     Nome do Estado
# Onde tem essas informacoes? API chamada GEOPY
# Qual dados eu tenho na minha base que eu consiga fazer o link?
# Como coletar esse dado e como anexa-lo no conjunto original?

# %%
import pandas as pd 
data = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')
from geopy.geocoders import Nominatim

# %%
# Creating empty rows

data['road'] = "NA"
data['house_number'] = "NA"
data['neighbourhood'] = "NA"
data['city'] = "NA"
data['country'] = "NA"
data['state'] = "NA"

# Initialize Nominatim API
geolocator = Nominatim (user_agent='geoapiExercises')

i = 0
for i in range(len(data)):
    print('Loop: {} / {}'.format(i,len(data)))
    #make query
    query = str(data.loc[i,'lat']) + ',' + str(data.loc[i,'long'])

    # API Request
    response = geolocator.reverse (query)

    if 'house_number' in response.raw['address']:
         data.loc[i,'house_number']  = response.raw['address']['house_number']
        
    if 'road' in response.raw['address']:
        data.loc[i,'road'] = response.raw['address']['road']
    
    if 'neighbourhood' in response.raw['address']:
        data.loc[i,'neighbourhood'] = response.raw['address']['neighbourhood']
    
    if 'city' in response.raw['address']:
        data.loc[i,'city']          = response.raw['address']['city']
    
    if 'country' in response.raw['address']:
        data.loc[i,'country']       = response.raw['address']['country']
    
    if 'state' in response.raw['address']:
        data.loc[i,'state']         = response.raw['address']['state']

# print(response.raw['address']['road'])
# print(response.raw['address']['house_number'])
# print(response.raw['address']['neighbourhood'])
# print(response.raw['address']['city'])
# print(response.raw['address']['country'])
# print(response.raw['address']['state'])
# Out:
# Loop: 0 / 21613
# Loop: 1 / 21613
# Loop: 2 / 21613
# Loop: 3 / 21613
# Loop: 4 / 21613
# Loop: 5 / 21613
# Loop: 6 / 21613
# Loop: 7 / 21613
# Loop: 8 / 21613
# Loop: 9 / 21613
# Loop: 10 / 21613
# Loop: 11 / 21613
# Loop: 12 / 21613
# Loop: 13 / 21613
# Loop: 14 / 21613
# Loop: 15 / 21613
# Loop: 16 / 21613
# Loop: 17 / 21613
# Loop: 18 / 21613
# Loop: 19 / 21613
# Loop: 20 / 21613
# Loop: 21 / 21613
# Loop: 22 / 21613
# Loop: 23 / 21613
# Loop: 24 / 21613
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-35abb427c786> in <module>
#      18
#      19     # API Request
# ---> 20     response = geolocator.reverse (query)
#      21
#      22     if 'house_number' in response.raw['address']:
#
# ~\anaconda3\lib\site-packages\geopy\geocoders\nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
# ...

# %% [markdown]
# # Filtros iterativos no mapa

# %%
import plotly.express as px

data = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')
houses = data[['id','lat','long','price']].copy()

#define price
for i in range (len(houses)):
    if houses.loc[i,'price'] <= 321950:
        houses.loc[i,'level'] = 0
        
    elif (houses.loc[i,'price'] > 321950) & (houses.loc[i,'price'] <= 450000):
        houses.loc[i,'level'] = 1
    
    elif (houses.loc[i,'price'] > 450000) & (houses.loc[i,'price'] <= 645000):
        houses.loc[i,'level'] = 2
        
    else: 
        houses.loc[i,'level'] = 3  

houses['level'] = houses['level'].astype(int)

fig = px.scatter_mapbox(houses,
                       lat = 'lat',
                       lon = 'long',
                       size= 'price',
                       color='level',
                       color_continuous_scale=px.colors.cyclical.IceFire,
                       size_max=15,
                       zoom=10)

fig.update_layout(mapbox_style='open-street-map')
fig.update_layout(height=600, margin = {'t':0,'l':0,'r':0,'b':0})
fig.show()

# %% [markdown]
# # Adicionando Filtros Iterativos

# %%
import ipywidgets as widgets
from ipywidgets import fixed
import pandas as pd 
import plotly.express as px 

df = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')
houses = df[['id','lat','long','price']].copy()


df['is_waterfront'] = df['waterfront'].apply(lambda x: 'yes' if x==1 else 'no')

df['level'] = df['price'].apply(lambda x: 0 if x < 321950 else
                               1 if (x >= 321950) & (x < 450000) else
                               2 if (x >= 450000) & (x < 645000) else
                               3 )

df['level'] = df['level'].astype(int)
style = {'description_width':'initial'}

# Iterative buttons
price_limit = widgets.IntSlider( 
    value = 540000,
    min = 75000,
    max = 7700000,
    step = 1,
    description='Maximum Price',
    disable = False,
    style = style)

waterfront_bar = widgets.Dropdown(
    options = df['is_waterfront'].unique().tolist(),
    value = 'yes',
    description = 'Water View',
    disable = False)

def update_map (df,waterfront,price_limit):
    houses = df[(df['price'] <= price_limit) &
                (df['is_waterfront'] == waterfront)]
    [['id','lat','long','price','level']]
    
    fig = px.scatter_mapbox (houses,
                            lat='lat',
                            lon='long',
                            color='level',
                            size='price',
                            color_continuous_scale=px.colors.cyclical.IceFire,
                            size_max=15,
                            zoom=10)
    fig.update_layout(mapbox_style='open-street-map')
    fig.update_layout(height = 600, margin={'r':0,'t':0,'l':0,'b':0})
    fig.show()

# %%
widgets.interactive(update_map,df=fixed(df),
                    waterfront=waterfront_bar,
                    price_limit=price_limit)
# Out:
# interactive(children=(Dropdown(description='Water View', index=1, options=('no', 'yes'), value='yes'), IntSlid…

# %% [markdown]
# # Iteratividade com o dashboard

# %%
import pandas as pd
import ipywidgets as widgets
from matplotlib import gridspec
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')

data['year'] = pd.to_datetime(data['date']).dt.strftime('%Y')
data['date'] = pd.to_datetime(data['date']).dt.strftime('%Y-%m-%d')
data['year_week'] = pd.to_datetime(data['date']).dt.strftime('%Y-%U')

# Widgets to control data
date_limit = widgets.SelectionSlider(
    options = data['date'].sort_values().unique().tolist(),
    value = '2014-12-01',
    description = 'Disponivel',
    continuous_update=False,
    orientation='horizontal',
    readout=True)

def update_map (data,limit):
    #Filter Data
    df = data[data['date'] >= limit].copy()
    
    fig = plt.figure(figsize=(21,12))
    specs = gridspec.GridSpec(nrows = 2, ncols= 2, figure=fig)
    
    ax1 = fig.add_subplot(specs[0,:])
    ax2 = fig.add_subplot(specs[1,0])
    ax3 = fig.add_subplot(specs[1,1])
    
    by_year = df[['price','year']].groupby('year').sum().reset_index()
    ax1.bar(by_year['year'],by_year['price'])
    
    by_date = df[['price','date']].groupby('date').mean().reset_index()
    ax2.plot(by_date['date'],by_date['price'])
    ax2.set_title('Title: Average Price by date')
    
    
    by_year_week = df[['price','year_week']].groupby('year_week').mean().reset_index()
    ax3.bar(by_year_week['year_week'],by_year_week['price'])
    ax3.set_title('Average Price of Week of Year')
    plt.xticks(rotation=60);

# %%
widgets.interactive(update_map,data=fixed(data), limit = date_limit)
# Out:
# interactive(children=(SelectionSlider(continuous_update=False, description='Disponivel', index=212, options=('…

# %% [markdown]
# # Exercicios

# %%
#1. Qual a media do preco de compra do imoveis por nivel?
# Nivel 0: Preco entre $0 e $321,950
# Nivel 1: Preco entre $321,950 e $450,000
# Nivel 2: Preco entre $450,000 e $650,000
# Nivel 3: Preco acima de $650,000

# %%
import pandas as pd 

data = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')

data ['level'] = "NA"
i = 0 

for i in range(len(data)):

    if (data.loc[i,'price'] > 0) & (data.loc[i,'price'] <= 321950):
        data.loc[i,'level'] = 0

    elif (data.loc[i,'price'] > 321950) & (data.loc[i,'price'] <= 450000):
        data.loc[i,'level'] = 1

    elif (data.loc[i,'price'] > 450000) & (data.loc[i,'price'] < 650000):
        data.loc[i,'level'] = 2

    else:
        data.loc[i,'level'] = 3

data[['price','level']].groupby('level').mean().reset_index()
# Out:
#    level          price
# 0      0  251557.649889
# 1      1  385688.681502
# 2      2  540712.141567
# 3      3  990661.889369

# %%
#2. Qual a media do tamanho da sala de estar dos imoveis por Size?
# Size 0: Tamanho entre 0 e 1427 sqft
# Size 1: Tamanho entre 1427 e 1910 sqft
# Size 2: Tamanho entre 1910 e 2550 sqft
# Size 3: Tamanho acima de 2250 sqft

# %%
data['size'] = "NA"

i=0

for i in range(len(data)):
    
    if (data.loc[i,'sqft_living'] > 0) & (data.loc[i,'sqft_living'] <= 1427):
        data.loc[i,'size'] = 0
    
    elif (data.loc[i,'sqft_living'] > 1427) & (data.loc[i,'sqft_living'] <= 1910):
        data.loc[i,'size'] = 1
        
    elif (data.loc[i,'sqft_living'] > 1910) & (data.loc[i,'sqft_living'] <= 2250):
        data.loc[i,'size'] = 2
        
    else:
        data.loc[i,'size'] = 3

data[['sqft_living','size']].groupby('size').mean().reset_index()
# Out:
#    size  sqft_living
# 0     0  1123.832531
# 1     1  1664.962334
# 2     2  2080.762395
# 3     3  3056.846955

# %%
#3. Adicione as seguintes informacoes ao conjunto de dados original:
# Place ID: Identificacao da localizacao
# OSM Type: Open Street Map type
# Country: Nome do Pais
# Country Code: Codigo do pais

# %%
import pandas as pd 
from geopy.geocoders import Nominatim

data = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')

data['Place ID'] = "NA"
data['OSM Type'] = "NA"
data['Country'] = "NA"
data['Country Code'] = "NA"

# Initialize Nominatim API
geolocator = Nominatim (user_agent='geoapiExercises')

# %%
#response.raw['place_id'] 
# response.raw
# response.raw ['address']['country']
# response.raw ['address']['country_code']

# %%
i=0
for i in range(len(data)):
    print('Loop: {}/{}'. format(i,len(data)))
    query = str(data.loc[i,'lat']) + ',' + str(data.loc[i,'long'])
    
    # API Request
    response = geolocator.reverse(query)
    
    if 'place_id' in response.raw:
        data.loc[i,'Place ID'] = (response.raw['place_id'])
    
    if 'osm_type' in response.raw:
        data.loc[i,'OSM Type'] = response.raw['osm_type']
    
    if 'country' in response.raw ['address']:
        data.loc[i,'Country'] = response.raw ['address']['country']
    
    if 'country_code' in response.raw ['address']:
        data.loc[i,'Country Code'] = response.raw ['address']['country_code']
# Out:
# Loop: 0/21613
# Loop: 1/21613
# Loop: 2/21613
# Loop: 3/21613
# Loop: 4/21613
# Loop: 5/21613
# Loop: 6/21613
# Loop: 7/21613
# Loop: 8/21613
# Loop: 9/21613
# Loop: 10/21613
# Loop: 11/21613
# Loop: 12/21613
# Loop: 13/21613
# Loop: 14/21613
# Loop: 15/21613
# Loop: 16/21613
# Loop: 17/21613
# Loop: 18/21613
# Loop: 19/21613
# Loop: 20/21613
# Loop: 21/21613
# Loop: 22/21613
# Loop: 23/21613
# Loop: 24/21613
# Loop: 25/21613
# Loop: 26/21613
# Loop: 27/21613
# Loop: 28/21613
# Loop: 29/21613
# Loop: 30/21613
# Loop: 31/21613
# Loop: 32/21613
# Loop: 33/21613
# Loop: 34/21613
# Loop: 35/21613
# Loop: 36/21613
# Loop: 37/21613
# Loop: 38/21613
# Loop: 39/21613
# Loop: 40/21613
# Loop: 41/21613
# Loop: 42/21613
# Loop: 43/21613
# Loop: 44/21613
# Loop: 45/21613
# Loop: 46/21613
# Loop: 47/21613
# Loop: 48/21613
# Loop: 49/21613
# Loop: 50/21613
# ---------------------------------------------------------------------------
# ...

# %%
data.iloc[1:50,:]
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# 11  9212900260  20140527T000000   468000.0         2       1.00         1160
# ...

# %%
# Adicione os seguintes filtros no mapa:
# - Tamanho minimo da area de sala de estar
# - Numero minimo de banheiros
# - Valor maximo do preco
# - Tamanho maximo da area do porao
# - Filtro das condicoes do imovel
# - Filtro por ano de construcao

# %%
data['yr_built']
# Out:
# 0        1970
# 1        1970
# 2        1970
# 3        1970
# 4        1970
#          ...
# 21608    1970
# 21609    1970
# 21610    1970
# 21611    1970
# 21612    1970
# Name: yr_built, Length: 21613, dtype: object

# %%
import pandas as pd 
import ipywidgets as widgets
from ipywidgets import fixed 
import plotly.express as ptx

data = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')

style = {'description_width':'initial'}


min_living_room_size = widgets.FloatSlider( value=0,
                                            min=0,
                                            max=13540,
                                            step=5,
                                            description='Minimum living room size in sqft:',
                                            disabled=False,
                                            continuous_update=False,
                                            orientation='horizontal',
                                            readout=True,
                                            )

min_bathroom_number = widgets.FloatSlider(  value=0,
                                            min=data['bathrooms'].min(),
                                            max=data['bathrooms'].max(),
                                            step=0.5,
                                            description='Minimum bathroom number:',
                                            disabled=False,
                                            continuous_update=False,
                                            orientation='horizontal',
                                            readout=True,
                                            readout_format='.1f',)

price_limit = widgets.IntSlider(            value = 75000,
                                            min = 75000,
                                            max = 7700000,
                                            step = 1000,
                                            description='Maximum Price',
                                            disable = False,
                                            style = style)


max_sqft_basement_size = widgets.FloatSlider(value=0,
                                            min=data['sqft_basement'].min(),
                                            max=data['sqft_basement'].max(),
                                            step=5,
                                            description='Maximum basement size in sqft:',
                                            disabled=False,
                                            continuous_update=False,
                                            orientation='horizontal',
                                            readout=True,
                                            )

data['condition'] = data['condition'].astype(str)
house_condition = widgets.Dropdown(         options=['1','2','3','4','5'],
                                            value='1',
                                            description='Condition:',
                                            disabled=False,)

year_built = widgets.IntSlider(             value = 1970,
                                            min = 1950,
                                            max = 2020,
                                            step = 5,
                                            description='Year Built:',
                                            disable = False,
                                            style = style)



def update_map (data,living_room, bathroom_number, limit,basement_size,conditions,built):

    df = data[
    (data['sqft_living'] > living_room) & 
    (data['bathrooms'] > bathroom_number) & 
    (data['price'] < limit) & 
    (data['sqft_basement'] < basement_size) & 
    (data['condition'] == conditions) &
    (data['yr_built'] == built)
    ]
    data[['price','lat','long','sqft_living','bathrooms','condition','yr_built','sqft_basement']].copy()

    fig = ptx.scatter_mapbox(df,
                            lat='lat',
                            lon='long',
                            color_continuous_scale=ptx.colors.cyclical.IceFire,
                            size_max=15,
                            zoom=10)
    fig.update_layout(mapbox_style='open-street-map')
    fig.update_layout(height = 600, margin={'r':0,'t':0,'l':0,'b':0})
    fig.show()

# %%
 widgets.interactive(update_map,
                     data = fixed(data), 
                     living_room = min_living_room_size, 
                     bathroom_number = min_bathroom_number,
                     limit = price_limit,
                     basement_size = max_sqft_basement_size,
                     conditions = house_condition,
                     built = year_built
                     )
# Out:
# interactive(children=(FloatSlider(value=0.0, continuous_update=False, description='Minimum living room size in…

# %%
#5. Adicione os seguintes filtros no Dashboard
#  - Filtro por data disponivel para compra
#  - Filtro por ano de renovacao
#  - Filtro se possui vista para agua ou nao

# %%
import pandas as pd
import ipywidgets as widgets
from ipywidgets import fixed
from matplotlib import gridspec
from matplotlib import pyplot as plt

data = pd.read_csv('DataSets/kc_house_data.csv/kc_house_data.csv')

data['date'] = pd.to_datetime(data['date']).dt.strftime('%m-%d-%Y')

data['is_waterfront'] = "NA"
i=0

for i in range(len(data)):
    
    if data.loc[i,'waterfront'] == 0:
        data.loc[i,'is_waterfront'] = 'No'
    
    if data.loc[i,'waterfront'] == 1:
        data.loc[i,'is_waterfront'] = 'Yes'


        


# Widgets to control data

waterfront_view = widgets.Dropdown(         options=['Yes','No'],
                                            value='Yes',
                                            description='Waterfront View:',
                                            disabled=False,)


date_limit = widgets.SelectionSlider(       options = data['date'].sort_values(ascending = False).unique().tolist(),
                                            value = '12-01-2014',
                                            description = 'Available:',
                                            continuous_update=False,
                                            orientation='horizontal',
                                            readout=True)


renovation_limit = widgets.SelectionSlider( options = data['yr_renovated'].sort_values().unique().tolist() ,
                                            value = 0,
                                            description = 'Year Renovated:',
                                            continuous_update=False,
                                            orientation='horizontal',
                                            readout=True)

def update_map (data,waterfront,limit,renovation):
    
    df = data[(data['is_waterfront'] == waterfront) &
              (data['date'] >= limit) &
              (data['yr_renovated'] == renovation)][['price','yr_renovated','is_waterfront','date']].copy()
    
    fig = plt.figure(figsize=(10,12))
    specs = gridspec.GridSpec(ncols=2,nrows = 2,figure=fig)
    
    ax1 = fig.add_subplot(specs[0,:])
    ax2 = fig.add_subplot(specs[1,0])
    ax3 = fig.add_subplot(specs[1,1])
    
    by_yr_renovated = df[['price', 'yr_renovated']].groupby('yr_renovated').mean().reset_index()
    ax1.bar(by_yr_renovated['yr_renovated'],by_yr_renovated['price'])
    ax1.set_title('Title: Average Price by Year Renovated')
    
    by_waterfront_view = df[['is_waterfront','price']].groupby('is_waterfront').mean().reset_index()
    ax2.bar(by_waterfront_view['is_waterfront'],by_waterfront_view['price'])
    ax2.set_title('Title: Average Price by Waterfront View')
    
    by_date_limit = df[['date','price']].groupby('date').mean().reset_index()
    ax3.bar(by_date_limit['date'],by_date_limit['price'])
    ax3.set_title('Title: Average Price by Date')
    plt.xticks(rotation=60)

# %%
widgets.interactive(update_map,data = fixed(data), waterfront = waterfront_view, limit = date_limit, renovation = renovation_limit)
# Out:
# interactive(children=(Dropdown(description='Waterfront View:', options=('Yes', 'No'), value='Yes'), SelectionS…
